# %%
from distributed import Executor, progress
exc = Executor('172.31.11.71:8888', set_as_default=True)
exc
# Out:
# c:\users\chai_\appdata\local\programs\python\python36\lib\site-packages\distributed\client.py:2800: UserWarning: Executor has been renamed to Client
#   warnings.warn("Executor has been renamed to Client")
# distributed.utils - ERROR - Timed out trying to connect to 'tcp://172.31.11.71:8888' after 5 s: connect() didn't finish in time
# Traceback (most recent call last):
#   File "c:\users\chai_\appdata\local\programs\python\python36\lib\site-packages\distributed\comm\core.py", line 185, in connect
#     quiet_exceptions=EnvironmentError)
#   File "c:\users\chai_\appdata\local\programs\python\python36\lib\site-packages\tornado\gen.py", line 1055, in run
#     value = future.result()
#   File "c:\users\chai_\appdata\local\programs\python\python36\lib\site-packages\tornado\concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
# tornado.gen.TimeoutError: Timeout
#
# ...
