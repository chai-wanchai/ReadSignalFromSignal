# %%
##  Select row  ###

# %%
import csv
import io
import pandas as pd
import datetime as T
import dask.dataframe as dd
import os
import numpy as np

# %%
directory = os.path.normpath("C:\\Users\\chai_\\Desktop\\edf\\Tran.csv")
outfile ='C:\\Users\\chai_\\Desktop\\OutToAnalysis.csv'
s = T.datetime.now()

# %%
df = pd.read_csv(directory,dtype=object)

# %%
Signal = ['subject','epoch',
          'SaO2_min', 'SaO2_max', 'SaO2_avg', 'SaO2_SD', 'SaO2_kurtosis',
          'PR_min', 'PR_max', 'PR_avg', 'PR_SD', 'PR_kurtosis',
          'position_min', 'position_max', 'position_avg', 'position_SD', 'position_kurtosis',
          'light_min', 'light_max', 'light_avg', 'light_SD', 'light_kurtosis',
          'ox_stat_min', 'ox_stat_max', 'ox_stat_avg', 'ox_stat_SD', 'ox_stat_kurtosis',
          'airflow_min', 'airflow_max', 'airflow_avg', 'airflow_SD', 'airflow_kurtosis',
          'ThorRes_min', 'ThorRes_max', 'ThorRes_avg', 'ThorRes_SD', 'ThorRes_kurtosis',
          'AbdoRes_min', 'AbdoRes_max', 'AbdoRes_avg', 'AbdoRes_SD', 'AbdoRes_kurtosis',
          'EOG(L)_min', 'EOG(L)_max', 'EOG(L)_avg', 'EOG(L)_SD', 'EOG(L)_kurtosis',
          'EOG(R)_min', 'EOG(R)_max', 'EOG(R)_avg', 'EOG(R)_SD', 'EOG(R)_kurtosis',
          'EEG(sec)_min', 'EEG(sec)_max', 'EEG(sec)_avg', 'EEG(sec)_SD', 'EEG(sec)_kurtosis',
          'EEG_min', 'EEG_max', 'EEG_avg', 'EEG_SD', 'EEG_kurtosis',
          'ECG_min', 'ECG_max', 'ECG_avg', 'ECG_SD', 'ECG_kurtosis',
          'EMG_min', 'EMG_max', 'EMG_avg', 'EMG_SD', 'EMG_kurtosis',
          'stage']

# %%
df
# Out:
#                         subject            shhs2-200077           shhs2-200078
# 0                   e1_SaO2_min      95.115587090867479     94.139009689478911
# 1                   e1_SaO2_max      96.092164492256046     96.092164492256046
# 2                   e1_SaO2_avg       95.40856031128402     94.724956130312023
# 3                    e1_SaO2_SD     0.44752398638463836    0.59669864851285104
# 4              e1_SaO2_kurtosis      -1.238095238095017    -0.6428571428570491
# 5                     e1_PR_min      75.199511711299309      64.26184481574731
# 6                     e1_PR_max      87.309071488517588     66.214999618524459
# 7                     e1_PR_avg      79.952188398057004     64.978001576765593
# 8                      e1_PR_SD      3.5471260570953196    0.56005576367918242
# 9                e1_PR_kurtosis     -1.1104010349067643   -0.49415631848060837
# 10              e1_position_min                     1.0                    2.0
# 11              e1_position_max                     3.0                    2.0
# 12              e1_position_avg      2.8999999999999999                    2.0
# 13               e1_position_SD     0.39581140290126388                    0.0
# 14         e1_position_kurtosis      15.593481213218652                   -3.0
# 15                 e1_light_min                     0.0                    0.0
# 16                 e1_light_max                     1.0                    0.0
# 17                 e1_light_avg    0.033333333333333333                    0.0
# 18                  e1_light_SD     0.17950549357115009                    0.0
# 19            e1_light_kurtosis       25.03448275862072                   -3.0
# 20               e1_ox_stat_min                     0.0                    0.0
# 21               e1_ox_stat_max                     2.0                    0.0
# 22               e1_ox_stat_avg     0.26666666666666666                    0.0
# 23                e1_ox_stat_SD     0.67986926847903806                    0.0
# 24          e1_ox_stat_kurtosis       2.653846153846149                   -3.0
# 25               e1_airflow_min                    -1.0   -0.63137254901960782
# 26               e1_airflow_max     0.99215686274509807     0.8901960784313725
# 27               e1_airflow_avg   -0.048431372549019601   0.092287581699346408
# 28                e1_airflow_SD     0.64573178437910783    0.41355246306994975
# 29          e1_airflow_kurtosis      -1.256496443468154    -1.1787716502369128
# ...                         ...                     ...                    ...
# 120031         e1691_EOG(L)_max                     NaN                    NaN
# 120032         e1691_EOG(L)_avg                     NaN                    NaN
# 120033          e1691_EOG(L)_SD                     NaN                    NaN
# 120034    e1691_EOG(L)_kurtosis                     NaN                    NaN
# 120035         e1691_EOG(R)_min                     NaN                    NaN
# 120036         e1691_EOG(R)_max                     NaN                    NaN
# 120037         e1691_EOG(R)_avg                     NaN                    NaN
# 120038          e1691_EOG(R)_SD                     NaN                    NaN
# 120039    e1691_EOG(R)_kurtosis                     NaN                    NaN
# 120040       e1691_EEG(sec)_min                     NaN                    NaN
# 120041       e1691_EEG(sec)_max                     NaN                    NaN
# 120042       e1691_EEG(sec)_avg                     NaN                    NaN
# 120043        e1691_EEG(sec)_SD                     NaN                    NaN
# 120044  e1691_EEG(sec)_kurtosis                     NaN                    NaN
# 120045            e1691_EEG_min                     NaN                    NaN
# 120046            e1691_EEG_max                     NaN                    NaN
# 120047            e1691_EEG_avg                     NaN                    NaN
# 120048             e1691_EEG_SD                     NaN                    NaN
# 120049       e1691_EEG_kurtosis                     NaN                    NaN
# 120050            e1691_ECG_min                     NaN                    NaN
# 120051            e1691_ECG_max                     NaN                    NaN
# 120052            e1691_ECG_avg                     NaN                    NaN
# 120053             e1691_ECG_SD                     NaN                    NaN
# 120054       e1691_ECG_kurtosis                     NaN                    NaN
# 120055            e1691_EMG_min                     NaN                    NaN
# 120056            e1691_EMG_max                     NaN                    NaN
# 120057            e1691_EMG_avg                     NaN                    NaN
# 120058             e1691_EMG_SD                     NaN                    NaN
# 120059       e1691_EMG_kurtosis                     NaN                    NaN
# 120060              e1691_stage                     NaN                    NaN
#
# [120061 rows x 3 columns]
